# %%
import pandas as pd

# %%
pitchers = pd.read_csv('pitchers_bbr_full_TOTs_removed.csv')

# %%
pitchers.head(20)
# Out:
#     Year   Age   Tm  Lg     W     L   W-L%     ERA     G    GS  ...   gmLI  \
# 0   1997  20.0  LAD  NL   2.0   3.0  0.400   3.830  14.0   5.0  ...  0.660
# 1   1998  21.0  LAD  NL   3.0   5.0  0.427   4.496  19.0  10.0  ...  0.808
# 2   1999  22.0  CIN  NL   2.0   2.0  0.500   3.790  65.0   1.0  ...  1.270
# 3   2000  23.0  CIN  NL   2.0   1.0  0.667   4.530  62.0   0.0  ...  1.200
# 4   2001  24.0  CIN  NL   2.0   6.0  0.250   4.920  35.0   6.0  ...  1.210
# 5   2002  25.0  COL  NL   4.0   4.0  0.292   5.336  58.0   5.0  ...  0.710
# 6   2003  26.0  PIT  NL   0.0   0.0    NaN  10.643  15.0   0.0  ...  0.508
# 7   2004  27.0  KCR  AL   4.0   8.0  0.333   4.750  40.0  12.0  ...  1.430
# 8   2005  28.0  SDP  NL   3.0   2.0  0.600   5.150  36.0   1.0  ...  0.660
# 9   2006  29.0  MIN  AL   5.0   0.0  1.000   0.890  66.0   0.0  ...  1.040
# 10  2007  30.0  MIN  AL   2.0   1.0  0.667   3.990  50.0   0.0  ...  1.060
# ...

# %%
pitchers.shape
# Out:
# (8140, 53)

# %%
count_nan = len(pitchers) - pitchers.count()
print(count_nan)
# Out:
# Year         0
# Age          0
# Tm           0
# Lg           0
# W            0
# L            0
# ERA          6
# G            0
# GS           0
# GF           0
# CG           0
# SHO          0
# SV           0
# IP           0
# H            0
# R            0
# ER           0
# HR           0
# BB           0
# IBB          0
# SO           0
# HBP          0
# BK           0
# WP           0
# BF           0
# ERA+       166
# FIP         11
# WHIP        11
# H9          11
# HR9         11
# BB9         11
# SO9         11
# SO/W       154
# Awards       0
# RA9         11
# RA9opp      11
# RA9def      11
# RA9role     11
# PPFp         1
# RA9avg      11
# RAA         11
# WAA         11
# WAAadj       1
# WAR         11
# RAR         11
# waaWL%      11
# 162WL%      11
# key          0
# Tm2          0
# Tm3          0
# dtype: int64

# %%
pitchers.shape
# Out:
# (8140, 50)

# %%
pitchers.columns
# Out:
# Index(['Year', 'Age', 'Tm', 'Lg', 'W', 'L', 'W-L%', 'ERA', 'G', 'GS', 'GF',
#        'CG', 'SHO', 'SV', 'IP', 'H', 'R', 'ER', 'HR', 'BB', 'IBB', 'SO', 'HBP',
#        'BK', 'WP', 'BF', 'ERA+', 'FIP', 'WHIP', 'H9', 'HR9', 'BB9', 'SO9',
#        'SO/W', 'Awards', 'RA9', 'RA9opp', 'RA9def', 'RA9role', 'PPFp',
#        'RA9avg', 'RAA', 'WAA', 'gmLI', 'WAAadj', 'WAR', 'RAR', 'waaWL%',
#        '162WL%', 'Salary', 'key', 'Tm2', 'Tm3'],
#       dtype='object')

# %%
pitchers = pitchers.drop(['Salary', 'W-L%', 'gmLI'], axis=1)

# %%
pitchers.Tm2.fillna(pitchers.Tm, inplace=True)
pitchers.Tm3.fillna(pitchers.Tm2, inplace=True)
pitchers.Awards.fillna('no_award', inplace=True)

# %%
pitchers.dropna().shape
# Out:
# (7865, 50)

# %% [markdown]
# If a this point we just drop all lines with NaN, it seems that we are loosing a lot of players.
#
# can we fill the NaN of ERA+?
