# %%
import requests
import bs4
import pandas as pd

# %%
year = 2016
url = 'https://www.baseball-reference.com/awards/awards_' + str(2016) + '.shtml'

# %%
res = requests.get(url)
soup=bs4.BeautifulSoup(res.text, 'html.parser')

# %%
tempCols = ['rk', 'name', 'team', 'votePoints',  'league','year', 'award']
colsReorg = ['year', 'award', 'rk', 'name', 'team', 'league', 'votePoints']

# %%
AlMvp = soup.find('div', {'id': 'all_AL_MVP_voting'})
NlMvp = soup.find('div', {'id': 'all_NL_MVP_voting'})
AlCy = soup.find('div', {'id': 'all_AL_CYA_voting'})
NlCy = soup.find('div', {'id': 'all_NL_CYA_voting'})
AlRookie = soup.find('div', {'id': 'all_AL_ROY_voting'})
NlRookie = soup.find('div', {'id': 'all_NL_ROY_voting'})
AlManager = soup.find('div', {'id': 'all_AL_MOY_voting'})
NlManager = soup.find('div', {'id': 'all_NL_MOY_voting'})

# %%
AlCy.find('span')['data-label'][3:-7].replace(' ','')
# Out:
# 'CyYoung'

# %%
tableAlMvp = bs4.BeautifulSoup(str(AlMvp).replace('<!--', ''), 'html.parser').find('table')
tableNlMvp = bs4.BeautifulSoup(str(NlMvp).replace('<!--', ''), 'html.parser').find('table')
tableAlCy = bs4.BeautifulSoup(str(AlCy).replace('<!--', ''), 'html.parser').find('table')
tableNlCy = bs4.BeautifulSoup(str(NlCy).replace('<!--', ''), 'html.parser').find('table')
tableAlRookie = bs4.BeautifulSoup(str(AlRookie).replace('<!--', ''), 'html.parser').find('table')
tableNlRookie = bs4.BeautifulSoup(str(NlRookie).replace('<!--', ''), 'html.parser').find('table')
tableAlManager = bs4.BeautifulSoup(str(AlManager).replace('<!--', ''), 'html.parser').find('table')
tableNlManager = bs4.BeautifulSoup(str(NlManager).replace('<!--', ''), 'html.parser').find('table')

# %%
divs = [AlMvp, NlMvp, AlCy, NlCy, AlRookie, NlRookie, AlManager, NlManager]
tables = [tableAlMvp, tableNlMvp, tableAlCy, tableNlCy, tableAlRookie, tableNlRookie, tableAlManager, tableNlManager]

# %%
df = pd.DataFrame(columns = colsReorg)


for div, tab in zip(divs, tables):

    dfs = pd.read_html(str(tab), header=0)
    _df = dfs[0]
    colsKeep = list(_df.columns)[:4]
    _df =_df[colsKeep]
    _df['league'] = div.find('span')['data-label'][:2].replace(' ','')
    _df['year'] = year
    _df['award'] = div.find('span')['data-label'][3:-7].replace(' ','')
    _df.columns = tempCols

    _df = _df[colsReorg]
    _df = _df.drop(_df.index[0])    
    df = df.append(_df)

df.head(30)
# Out:
# C:\Users\jfran\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\jfran\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\jfran\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
#     year award  rk               name team league votePoints
# 1   2016   MVP   1         Mike Trout  LAA     AL      356.0
# 2   2016   MVP   2       Mookie Betts  BOS     AL      311.0
# 3   2016   MVP   3        Jose Altuve  HOU     AL      227.0
# 4   2016   MVP   4     Josh Donaldson  TOR     AL      200.0
# 5   2016   MVP   5      Manny Machado  BAL     AL      150.0
# 6   2016   MVP   6        David Ortiz  BOS     AL      147.0
# 7   2016   MVP   7      Adrian Beltre  TEX     AL      135.0
# 8   2016   MVP   8      Robinson Cano  SEA     AL       79.0
# 9   2016   MVP   9     Miguel Cabrera  DET     AL       56.0
# 10  2016   MVP   9   Francisco Lindor  CLE     AL       56.0
# 11  2016   MVP  11       Zack Britton  BAL     AL       11.0
# 12  2016   MVP  12        Kyle Seager  SEA     AL       10.0
# 13  2016   MVP  13       Brian Dozier  MIN     AL        9.0
# 14  2016   MVP  14  Edwin Encarnacion  TOR     AL        7.0
# 15  2016   MVP  15        Nelson Cruz  SEA     AL        6.0
# 16  2016   MVP  16         Chris Sale  CHW     AL        3.0
# 17  2016   MVP  17       Jose Ramirez  CLE     AL        2.0
# 18  2016   MVP  17   Justin Verlander  DET     AL        2.0
# 19  2016   MVP  19         Adam Eaton  CHW     AL        1.0
# 20  2016   MVP  19       Corey Kluber  CLE     AL        1.0
# 21  2016   MVP  19      Evan Longoria  TBR     AL        1.0
# 1   2016   MVP   1        Kris Bryant  CHC     NL      415.0
# 2   2016   MVP   2      Daniel Murphy  WSN     NL      245.0
# 3   2016   MVP   3       Corey Seager  LAD     NL      240.0
# 4   2016   MVP   4      Anthony Rizzo  CHC     NL      202.0
# 5   2016   MVP   5      Nolan Arenado  COL     NL      199.0
# 6   2016   MVP   6    Freddie Freeman  ATL     NL      129.0
# 7   2016   MVP   7         Joey Votto  CIN     NL      100.0
# 8   2016   MVP   8    Yoenis Cespedes  NYM     NL       45.0
# 9   2016   MVP   9      Justin Turner  LAD     NL       44.0

# %%
df['votePoints'].sum()
# Out:
# 510.0
